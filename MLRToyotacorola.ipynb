# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/a856994/Downloads/datascience/ToyotaCorolla0.csv")

# %%
df=df[df.columns[[2,3,6,8,12,13,15,16,17]]]

# %%
df.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %%
df.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %%
df.dtypes
# Out:
# Price            int64
# Age_08_04        int64
# KM               int64
# HP               int64
# cc               int64
# Doors            int64
# Gears            int64
# Quarterly_Tax    int64
# Weight           int64
# dtype: object

# %%
df.tail()
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114

# %%
df.shape
# Out:
# (1436, 9)

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP           cc  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors        Gears  Quarterly_Tax      Weight
# count  1436.000000  1436.000000    1436.000000  1436.00000
# mean      4.033426     5.026462      87.122563  1072.45961
# std       0.952677     0.188510      41.128611    52.64112
# min       2.000000     3.000000      19.000000  1000.00000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %%
df.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.876590 -0.569960  0.314990  0.126389  0.185326
# Age_08_04     -0.876590   1.000000  0.505672 -0.156622 -0.098084 -0.148359
# KM            -0.569960   0.505672  1.000000 -0.333538  0.102683 -0.036197
# HP             0.314990  -0.156622 -0.333538  1.000000  0.035856  0.092424
# cc             0.126389  -0.098084  0.102683  0.035856  1.000000  0.079903
# Doors          0.185326  -0.148359 -0.036197  0.092424  0.079903  1.000000
# Gears          0.063104  -0.005364  0.015023  0.209477  0.014629 -0.160141
# Quarterly_Tax  0.219197  -0.198431  0.278165 -0.298432  0.306996  0.109363
# Weight         0.581198  -0.470253 -0.028598  0.089614  0.335637  0.302618
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063104       0.219197  0.581198
# Age_08_04     -0.005364      -0.198431 -0.470253
# KM             0.015023       0.278165 -0.028598
# ...

# %%
#EDA

# %%
#scatter plot

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["Age_08_04"],df["Price"])
plt.title("Age_08_04 vs Price",c="BLUE",size=14)
plt.xlabel("Age_08_04",c="red",size=13)
plt.ylabel("Price",c="green",size=13)
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(df["KM"],df["Price"])
plt.title("KM vs Price",c="BLUE",size=14)
plt.xlabel("KM",c="red",size=13)
plt.ylabel("Price",c="green",size=13)
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(df["HP"],df["Price"])
plt.title("HP vs Price",c="BLUE",size=14)
plt.xlabel("HP",c="red",size=13)
plt.ylabel("Price",c="green",size=13)
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(df["cc"],df["Price"])
plt.title("cc vs Price",c="BLUE",size=14)
plt.xlabel("cc",c="red",size=13)
plt.ylabel("Price",c="green",size=13)
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(df["Doors"],df["Price"])
plt.title("Doors vs Price",c="BLUE",size=14)
plt.xlabel("Doors",c="red",size=13)
plt.ylabel("Price",c="green",size=13)
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(df["Gears"],df["Price"])
plt.title("Gears vs Price",c="BLUE",size=14)
plt.xlabel("Gears",c="red",size=13)
plt.ylabel("Price",c="green",size=13)
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(df["Quarterly_Tax"],df["Price"])
plt.title("Quarterly_Tax vs Price",c="BLUE",size=14)
plt.xlabel("Quarterly_Tax",c="red",size=13)
plt.ylabel("Price",c="green",size=13)
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(df["Weight"],df["Price"])
plt.title("Weight vs Price",c="BLUE",size=14)
plt.xlabel("Weight",c="red",size=13)
plt.ylabel("Price",c="green",size=13)
# Out:
# Text(0, 0.5, 'Price')

# %%
#histogram plot
#skewness
#kurtosis

# %%
from scipy.stats import skew
from scipy.stats import kurtosis

# %%
df["Price"].hist()
# Out:
# <AxesSubplot:>

# %%
print(skew(df["Price"]))
print(kurtosis(df["Price"]))
# Out:
# 1.702104639170028
# 3.720603948160326

# %%
df["Age_08_04"].hist()
# Out:
# <AxesSubplot:>

# %%
print(skew(df["Age_08_04"]))
print(kurtosis(df["Age_08_04"]))
# Out:
# -0.8258380758865862
# -0.08054127692213431

# %%
df["KM"].hist()
# Out:
# <AxesSubplot:>

# %%
print(skew(df["KM"]))
print(kurtosis(df["KM"]))
# Out:
# 1.0148507004031242
# 1.675019881452977

# %%
df["HP"].hist()
# Out:
# <AxesSubplot:>

# %%
print(skew(df["HP"]))
print(kurtosis(df["HP"]))
# Out:
# 0.9548369218420583
# 8.801520963566196

# %%
df["cc"].hist()
# Out:
# <AxesSubplot:>

# %%
print(skew(df["cc"]))
print(kurtosis(df["cc"]))
# Out:
# 27.403130097971868
# 927.4695709923203

# %%
df["Doors"].hist()
# Out:
# <AxesSubplot:>

# %%
print(skew(df["Doors"]))
print(kurtosis(df["Doors"]))
# Out:
# -0.07631516995502334
# -1.872418913182589

# %%
df["Gears"].hist()
# Out:
# <AxesSubplot:>

# %%
print(skew(df["Gears"]))
print(kurtosis(df["Gears"]))
# Out:
# 2.2815732937623254
# 37.56814918731196

# %%
df["Quarterly_Tax"].hist()
# Out:
# <AxesSubplot:>

# %%
print(skew(df["Quarterly_Tax"]))
print(kurtosis(df["Quarterly_Tax"]))
# Out:
# 1.9917505644014402
# 4.279218018308278

# %%
df["Weight"].hist()
# Out:
# <AxesSubplot:>

# %%
print(skew(df["Weight"]))
print(kurtosis(df["Weight"]))
# Out:
# 3.1053912659728504
# 19.29137217683445

# %%
#bar graph

# %%
d1=df["Doors"].value_counts()

# %%
d1.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
d2=df["Gears"].value_counts()

# %%
d2.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
#box plot
df.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears',
#        'Quarterly_Tax', 'Weight'],
#       dtype='object')

# %%
df.boxplot(["Price"])
# Out:
# <AxesSubplot:>

# %%
df.loc[:,"Age_08_04"]
# Out:
# 0       23
# 1       23
# 2       24
# 3       26
# 4       30
#         ..
# 1431    69
# 1432    72
# 1433    71
# 1434    70
# 1435    76
# Name: Age_08_04, Length: 1436, dtype: int64

# %%
df.boxplot(["Age_08_04"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(["KM"])
# Out:
# <AxesSubplot:>

# %%
df.loc[:,"HP"]
# Out:
# 0        90
# 1        90
# 2        90
# 3        90
# 4        90
#        ...
# 1431     86
# 1432     86
# 1433     86
# 1434     86
# 1435    110
# Name: HP, Length: 1436, dtype: int64

# %%
df.boxplot(["HP"])
# Out:
# <AxesSubplot:>

# %%
df.loc[:,"cc"]
# Out:
# 0       2000
# 1       2000
# 2       2000
# 3       2000
# 4       2000
#         ...
# 1431    1300
# 1432    1300
# 1433    1300
# 1434    1300
# 1435    1600
# Name: cc, Length: 1436, dtype: int64

# %%
df.boxplot(["cc"])
# Out:
# <AxesSubplot:>

# %%
df.loc[:,"Doors"]
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1431    3
# 1432    3
# 1433    3
# 1434    3
# 1435    5
# Name: Doors, Length: 1436, dtype: int64

# %%
df.boxplot(["Doors"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(["Gears"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(["Quarterly_Tax"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(["Weight"])
# Out:
# <AxesSubplot:>

# %%
#pairplot

# %%
import seaborn as sns

# %%
sns.set_style(style="darkgrid")
sns.pairplot(df)

# %%
#heatmap based on correlation

# %%
import seaborn as sn

# %%
sn.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#distance plot
df.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears',
#        'Quarterly_Tax', 'Weight'],
#       dtype='object')

# %%
sns.distplot(df["Price"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df["Age_08_04"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age_08_04', ylabel='Density'>

# %%
sns.distplot(df["KM"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='KM', ylabel='Density'>

# %%
sns.distplot(df["HP"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HP', ylabel='Density'>

# %%
sns.distplot(df["cc"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cc', ylabel='Density'>

# %%
sns.distplot(df["Quarterly_Tax"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Quarterly_Tax', ylabel='Density'>

# %%
sns.distplot(df["Weight"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.distplot(df["Doors"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Doors', ylabel='Density'>

# %%
sns.distplot(df["Gears"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Gears', ylabel='Density'>

# %%
#log transformation

# %%
import numpy as np

# %%
df["Gears"]=np.log(df["Gears"])
sns.distplot(df["Gears"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Gears', ylabel='Density'>

# %%
df["Price"]=np.log(df["Price"])
sns.distplot(df["Price"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df["KM"]=np.log(df["KM"])
sns.distplot(df["KM"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='KM', ylabel='Density'>

# %%
df["HP"]=np.log(df["HP"])
sns.distplot(df["HP"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HP', ylabel='Density'>

# %%
df["cc"]=np.log(df["cc"])
sns.distplot(df["cc"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cc', ylabel='Density'>

# %%
df["Doors"]=np.log(df["Doors"])
sns.distplot(df["Doors"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Doors', ylabel='Density'>

# %%
df["Weight"]=np.log(df["Weight"])
sns.distplot(df["Weight"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
df["Age_08_04"]=np.log(df["Age_08_04"])
sns.distplot(df["Age_08_04"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age_08_04', ylabel='Density'>

# %%
df["Quarterly_Tax"]=np.log(df["Quarterly_Tax"])
sns.distplot(df["Quarterly_Tax"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Quarterly_Tax', ylabel='Density'>

# %%
df.head()
# Out:
#       Price  Age_08_04         KM       HP        cc     Doors     Gears  \
# 0  9.510445   3.135494  10.757605  4.49981  7.600902  1.098612  1.609438
# 1  9.528794   3.135494  11.197351  4.49981  7.600902  1.098612  1.609438
# 2  9.543235   3.178054  10.638520  4.49981  7.600902  1.098612  1.609438
# 3  9.612467   3.258097  10.778956  4.49981  7.600902  1.098612  1.609438
# 4  9.528794   3.401197  10.558414  4.49981  7.600902  1.098612  1.609438
#
#    Quarterly_Tax    Weight
# 0       5.347108  7.060476
# 1       5.347108  7.060476
# 2       5.347108  7.060476
# 3       5.347108  7.060476
# 4       5.347108  7.064759

# %%
df["Quarterly_Tax"]=(df["Quarterly_Tax"])**1/2
sns.distplot(df["Quarterly_Tax"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Quarterly_Tax', ylabel='Density'>

# %%
df["Age_08_04"]=(df["Age_08_04"])**1/2
sns.distplot(df["Age_08_04"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age_08_04', ylabel='Density'>

# %%
df["Price"]=(df["Price"])**1/2
sns.distplot(df["Price"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df["KM"]=(df["KM"])**1/2
sns.distplot(df["KM"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='KM', ylabel='Density'>

# %%
df["HP"]=(df["HP"])**1/2
sns.distplot(df["HP"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HP', ylabel='Density'>

# %%
df["cc"]=(df["cc"])**1/2
sns.distplot(df["cc"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cc', ylabel='Density'>

# %%
df["Doors"]=(df["Doors"])**1/2
sns.distplot(df["Doors"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Doors', ylabel='Density'>

# %%
df["Gears"]=(df["Gears"])**1/2
sns.distplot(df["Gears"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Gears', ylabel='Density'>

# %%
df["Weight"]=(df["Weight"])**1/2
sns.distplot(df["Weight"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
df.head()
# Out:
#       Price  Age_08_04        KM        HP        cc     Doors     Gears  \
# 0  4.755222   1.567747  5.378802  2.249905  3.800451  0.549306  0.804719
# 1  4.764397   1.567747  5.598676  2.249905  3.800451  0.549306  0.804719
# 2  4.771617   1.589027  5.319260  2.249905  3.800451  0.549306  0.804719
# 3  4.806233   1.629048  5.389478  2.249905  3.800451  0.549306  0.804719
# 4  4.764397   1.700599  5.279207  2.249905  3.800451  0.549306  0.804719
#
#    Quarterly_Tax    Weight
# 0       2.673554  3.530238
# 1       2.673554  3.530238
# 2       2.673554  3.530238
# 3       2.673554  3.530238
# 4       2.673554  3.532380

# %%
df["Weight"]=(df["Weight"])**2
sns.distplot(df["Weight"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
df["Price"]=(df["Price"])**2
sns.distplot(df["Price"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df["HP"]=(df["HP"])**2
sns.distplot(df["HP"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HP', ylabel='Density'>

# %%
df["KM"]=(df["KM"])**2
sns.distplot(df["KM"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='KM', ylabel='Density'>

# %%
df["cc"]=(df["cc"])**2
sns.distplot(df["cc"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cc', ylabel='Density'>

# %%
df["Doors"]=(df["Doors"])**2
sns.distplot(df["Doors"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Doors', ylabel='Density'>

# %%
df["Gears"]=(df["Gears"])**2
sns.distplot(df["Gears"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Gears', ylabel='Density'>

# %%
df["Age_08_04"]=(df["Age_08_04"])**2
sns.distplot(df["Gears"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Gears', ylabel='Density'>

# %%
df["Quarterly_Tax"]=(df["Quarterly_Tax"])**2
sns.distplot(df["Quarterly_Tax"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Quarterly_Tax', ylabel='Density'>

# %%
df.head()
# Out:
#        Price  Age_08_04         KM        HP        cc     Doors     Gears  \
# 0  22.612141   2.457831  28.931516  5.062072  14.44343  0.301737  0.647573
# 1  22.699479   2.457831  31.345169  5.062072  14.44343  0.301737  0.647573
# 2  22.768333   2.525007  28.294528  5.062072  14.44343  0.301737  0.647573
# 3  23.099878   2.653798  29.046475  5.062072  14.44343  0.301737  0.647573
# 4  22.699479   2.892036  27.870024  5.062072  14.44343  0.301737  0.647573
#
#    Quarterly_Tax     Weight
# 0        7.14789  12.462582
# 1        7.14789  12.462582
# 2        7.14789  12.462582
# 3        7.14789  12.462582
# 4        7.14789  12.477705

# %%
df
# Out:
#           Price  Age_08_04         KM        HP         cc     Doors  \
# 0     22.612141   2.457831  28.931516  5.062072  14.443430  0.301737
# 1     22.699479   2.457831  31.345169  5.062072  14.443430  0.301737
# 2     22.768333   2.525007  28.294528  5.062072  14.443430  0.301737
# 3     23.099878   2.653798  29.046475  5.062072  14.443430  0.301737
# 4     22.699479   2.892036  27.870024  5.062072  14.443430  0.301737
# ...         ...        ...        ...       ...        ...       ...
# 1431  19.903458   4.481914  24.652835  4.960302  12.852654  0.301737
# 1432  21.582805   4.572468  24.266433  4.960302  12.852654  0.301737
# 1433  20.465768   4.542610  23.726199  4.960302  12.852654  0.301737
# 1434  19.752499   4.512428  23.697498  4.960302  12.852654  0.301737
# 1435  19.565127   4.688813   0.000000  5.523629  13.607832  0.647573
#
#          Gears  Quarterly_Tax     Weight
# 0     0.647573       7.147890  12.462582
# 1     0.647573       7.147890  12.462582
# ...

# %%
df.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears',
#        'Quarterly_Tax', 'Weight'],
#       dtype='object')

# %%
df["Quarterly_Tax"]=1/df["Quarterly_Tax"]
sns.distplot(df["Quarterly_Tax"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Quarterly_Tax', ylabel='Density'>

# %%
df=df[np.isfinite(df.all(1))]

# %%
df["Age_08_04"]=1/df["Age_08_04"]
sns.distplot(df["Age_08_04"])
# Out:
# <AxesSubplot:xlabel='Age_08_04', ylabel='Density'>

# %%
df["Doors"]=1/df["Doors"]
sns.distplot(df["Doors"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Doors', ylabel='Density'>

# %%
df["Gears"]=1/df["Gears"]
sns.distplot(df["Gears"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Gears', ylabel='Density'>

# %%
df["Weight"]=1/df["Weight"]
sns.distplot(df["Weight"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
df=df[np.isfinite(df.all(1))]

# %%
df["KM"]=1/df["KM"]
sns.distplot(df["KM"])
# Out:
# <AxesSubplot:xlabel='KM', ylabel='Density'>

# %%
df["HP"]=1/df["HP"]
sns.distplot(df["HP"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HP', ylabel='Density'>

# %%
df["cc"]=1/df["cc"]
sns.distplot(df["cc"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cc', ylabel='Density'>

# %%
df["Price"]=1/df["Price"]
sns.distplot(df["Price"])
# Out:
# C:\Users\a856994\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df.head()
# Out:
#       Price  Age_08_04         KM        HP        cc     Doors     Gears  \
# 0  0.044224   2.457831  28.931516  0.197548  0.069236  3.314142  1.544228
# 1  0.044054   2.457831  31.345169  0.197548  0.069236  3.314142  1.544228
# 2  0.043921   2.525007  28.294528  0.197548  0.069236  3.314142  1.544228
# 3  0.043290   2.653798  29.046475  0.197548  0.069236  3.314142  1.544228
# 4  0.044054   2.892036  27.870024  0.197548  0.069236  3.314142  1.544228
#
#    Quarterly_Tax    Weight
# 0       0.139901  0.080240
# 1       0.139901  0.080240
# 2       0.139901  0.080240
# 3       0.139901  0.080240
# 4       0.139901  0.080143

# %%
# split X and y

# %%
df.columns.get_loc("Price")
# Out:
# 0

# %%
df.columns.get_loc("Age_08_04")

# %%
df.columns.get_loc("KM")

# %%
df.columns.get_loc("HP")

# %%
df.columns.get_loc("cc")

# %%
df.columns.get_loc("Doors")

# %%
df.columns.get_loc("Gears")

# %%
df.columns.get_loc("Quarterly_Tax")

# %%
df.columns.get_loc("Weight")

# %%
df.head()

# %%
#Data transformation

# %%
df.iloc[df.values==np.inf]
# Out:
# Empty DataFrame
# Columns: [Price, Age_08_04, KM, HP, cc, Doors, Gears, Quarterly_Tax, Weight]
# Index: []

# %%
from sklearn.preprocessing import StandardScaler

# %%
SS=StandardScaler()

# %%
df=SS.fit_transform(df)

# %%
df=pd.DataFrame(df)

# %%
df
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.966130 -1.732535 -0.259306  0.692599 -1.941825  1.078269  0.071848
# 1    -1.024185 -1.732535  0.319444  0.692599 -1.941825  1.078269  0.071848
# 2    -1.069639 -1.653536 -0.412045  0.692599 -1.941825  1.078269  0.071848
# 3    -1.284716 -1.502077 -0.231741  0.692599 -1.941825  1.078269  0.071848
# 4    -1.024185 -1.221908 -0.513833  0.692599 -1.941825  1.078269  0.071848
# ...        ...       ...       ...       ...       ...       ...       ...
# 1431  1.087299  0.647797 -1.285256  1.016309  1.492516  1.078269  0.071848
# 1432 -0.246516  0.754289 -1.377909  1.016309  1.492516  1.078269  0.071848
# 1433  0.616310  0.719175 -1.507447  1.016309  1.492516  1.078269  0.071848
# 1434  1.218308  0.683681 -1.514329  1.016309  1.492516  1.078269  0.071848
# 1435  1.383729  0.891111 -7.196558 -0.625805 -0.237958 -0.947215  0.071848
#
#              7         8
# 0    -1.281749 -1.836988
# ...

# %%
X=df.iloc[:,1:]

# %%
X
# Out:
#              1         2         3         4         5         6         7  \
# 0    -1.732535 -0.259306  0.692599 -1.941825  1.078269  0.071848 -1.281749
# 1    -1.732535  0.319444  0.692599 -1.941825  1.078269  0.071848 -1.281749
# 2    -1.653536 -0.412045  0.692599 -1.941825  1.078269  0.071848 -1.281749
# 3    -1.502077 -0.231741  0.692599 -1.941825  1.078269  0.071848 -1.281749
# 4    -1.221908 -0.513833  0.692599 -1.941825  1.078269  0.071848 -1.281749
# ...        ...       ...       ...       ...       ...       ...       ...
# 1431  0.647797 -1.285256  1.016309  1.492516  1.078269  0.071848  0.089842
# 1432  0.754289 -1.377909  1.016309  1.492516  1.078269  0.071848  0.089842
# 1433  0.719175 -1.507447  1.016309  1.492516  1.078269  0.071848  0.089842
# 1434  0.683681 -1.514329  1.016309  1.492516  1.078269  0.071848  0.089842
# 1435  0.891111 -7.196558 -0.625805 -0.237958 -0.947215  0.071848  4.016794
#
#              8
# 0    -1.836988
# 1    -1.836988
# 2    -1.836988
# ...

# %%
Y=df.iloc[:,0]

# %%
Y
# Out:
# 0      -0.966130
# 1      -1.024185
# 2      -1.069639
# 3      -1.284716
# 4      -1.024185
#           ...
# 1431    1.087299
# 1432   -0.246516
# 1433    0.616310
# 1434    1.218308
# 1435    1.383729
# Name: 0, Length: 1436, dtype: float64

# %%
#DATA PARTISION

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
X_train.shape
# Out:
# (1005, 8)

# %%
X_test.shape
# Out:
# (431, 8)

# %%
Y_train.shape
# Out:
# (1005,)

# %%
Y_test.shape
# Out:
# (431,)

# %%
#model fitting

# %%
import statsmodels.formula.api as smf

# %%
model=smf.ols("Price~Age_08_04+Weight+KM+HP+Quarterly_Tax+Doors+cc+Gears",data=df).fit()

# %%
sns.regplot(x="Age_08_04",y="Price",data=df)
sns.lmplot(x="Age_08_04",y="Price",data=df)

# %%
sns.regplot(x="KM",y="Price",data=df)
sns.lmplot(x="KM",y="Price",data=df)

# %%
sns.regplot(x="HP",y="Price",data=df)
sns.lmplot(x="HP",y="Price",data=df)

# %%
sns.regplot(x="cc",y="Price",data=df)
sns.lmplot(x="cc",y="Price",data=df)

# %%
sns.regplot(x="Doors",y="Price",data=df)
sns.lmplot(x="Doors",y="Price",data=df)

# %%
sns.regplot(x="Gears",y="Price",data=df)
sns.lmplot(x="Gears",y="Price",data=df)

# %%
sns.regplot(x="Weight",y="Price",data=df)
sns.lmplot(x="Weight",y="Price",data=df)

# %%
sns.regplot(x="Quarterly_Tax",y="Price",data=df)
sns.lmplot(x="Quarterly_Tax",y="Price",data=df)

# %%
import statsmodels.api as sm

# %%
qqplot=sm.qqplot(model.resid,line="q")

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     1131.
# Date:                Tue, 25 Jul 2023   Prob (F-statistic):               0.00
# Time:                        22:24:24   Log-Likelihood:                -12376.
# No. Observations:                1436   AIC:                         2.477e+04
# Df Residuals:                    1427   BIC:                         2.482e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
model.resid
# Out:
# 0      -3312.580505
# 1      -2522.355186
# 2      -2850.732460
# 3      -1476.496731
# 4      -2472.419010
#            ...
# 1431   -1293.758297
# 1432    2553.661579
# 1433      45.701993
# 1434   -1328.038121
# 1435   -3452.438333
# Length: 1436, dtype: float64

# %%
model.fittedvalues
# Out:
# 0       16812.580505
# 1       16272.355186
# 2       16800.732460
# 3       16426.496731
# 4       16222.419010
#             ...
# 1431     8793.758297
# 1432     8291.338421
# 1433     8454.298007
# 1434     8578.038121
# 1435    10402.438333
# Length: 1436, dtype: float64

# %%
model.resid.hist()
# Out:
# <AxesSubplot:>

# %%
plt.scatter(model.resid,model.fittedvalues)
plt.title("Residual plot")
plt.xlabel("model.resid")
plt.ylabel("model.fittedvalues")
# Out:
# Text(0, 0.5, 'model.fittedvalues')

# %%
model_influence = model.get_influence()
(cooks, pvalue) = model_influence.cooks_distance

cooks = pd.DataFrame(cooks)
cooks[0].describe()
# Out:
# count    1.436000e+03
# mean     5.756075e-02
# std      2.098641e+00
# min      7.279480e-12
# 25%      3.272575e-05
# 50%      1.409548e-04
# 75%      4.535454e-04
# max      7.952011e+01
# Name: 0, dtype: float64

# %%
import matplotlib.pyplot as plt
fig = plt.subplots()
plt.stem(np.arange(len(df)), np.round(cooks[0], 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
df.shape
# Out:
# (1436, 9)

# %%
# index and value of influencer where c is more than .5
cooks[0][cooks[0]>0.5]
# Out:
# 80     79.520106
# 221     1.021031
# 960     0.605000
# Name: 0, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()

# %%
LR.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
LR.intercept_
# Out:
# -0.008926776035167077

# %%
LR.coef_
# Out:
# array([ 0.70182477,  0.06070458,  0.18966245, -0.0707333 ,  0.01971149,
#         0.03821266,  0.05963798,  0.14991565])

# %%
#model prediction

# %%
Y_pred_train=LR.predict(X_train)

# %%
Y_pred_test=LR.predict(X_test)

# %%
Y_pred_train
# Out:
# array([-0.32041211,  0.44457247,  0.01063985, ...,  0.59666584,
#         0.57798126,  0.77575868])

# %%
Y_pred_test
# Out:
# array([-0.01750491,  0.40460195,  0.56930002,  0.38849004,  0.45311668,
#         0.57282268,  0.41863859,  0.6093481 , -0.88425102, -0.4930517 ,
#         0.26849722,  0.37929421, -0.49408324, -0.56231296,  0.21958467,
#         0.64227519, -0.36448882, -1.57571399,  0.60419942,  0.37454137,
#        -0.47512528, -2.18212853,  0.63833906,  0.14918069,  0.68116509,
#        -1.25091166,  0.27837504,  0.6256489 , -1.19033078, -0.92981471,
#         0.56996196,  0.23038869,  0.48274692,  0.18648116,  0.17534145,
#         0.58062816,  0.38308434,  0.21566798, -1.50695205,  0.16874229,
#         0.28096954,  0.3416237 ,  0.5848818 ,  0.96721499,  0.90996812,
#        -1.7410955 ,  0.32844419,  0.02231344,  0.57031616, -0.56042669,
#        -0.46494213,  1.01673425, -1.04268928, -1.22826851,  0.92854409,
#         0.57494816,  0.08119361,  0.01631054, -1.19260593, -1.93284647,
#        -0.53758407,  0.82636939,  0.58326488, -0.12758877, -0.63909332,
# ...

# %%
# model Evalution

# %%
from sklearn.metrics import mean_squared_error

# %%
mse1=mean_squared_error(Y_train,Y_pred_train)

# %%
mse2=mean_squared_error(Y_test,Y_pred_test)

# %%
print("Mean squared error of training data",mse1)
# Out:
# Mean squared error of training data 0.22789927507089947

# %%
print("Mean squared error of test data",mse2)
# Out:
# Mean squared error of test data 0.22827189695260988

# %%
import numpy as np

# %%
print("Root mean Squared error of training data is ",np.sqrt(mse1).round(3))
# Out:
# Root mean Squared error of training data is  0.477

# %%
print("Root mean Squared error of test data is ",np.sqrt(mse2).round(3))
# Out:
# Root mean Squared error of test data is  0.478

# %%
from sklearn.metrics import r2_score

# %%
print(" Squared error of test data is ",np.sqrt(mse1).round(3))
# Out:
#  Squared error of test data is  0.477

# %%
print(" Squared error of test data is ",np.sqrt(mse2).round(3))
# Out:
#  Squared error of test data is  0.478
